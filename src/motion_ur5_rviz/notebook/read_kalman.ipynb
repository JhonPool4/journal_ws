# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
folder = '../src/'
fn = "tmp.csv"
path = os.path.join(folder, fn)

# %%
df= pd.read_csv(path)

# %%
df.head()
# Out:
#        dpw1      dpw2          dpw3          dpw4      dpw5      dpw6  \
# 0  0.008486  0.000001  1.919999e-07 -9.361774e-07 -0.000003 -0.000115
# 1  0.016250  0.000058  2.223768e-05 -1.813389e-06 -0.000005 -0.000224
# 2  0.023339  0.000164  6.417877e-05 -2.633900e-06 -0.000008 -0.000325
# 3  0.029798  0.000316  1.241992e-04 -3.399938e-06 -0.000010 -0.000420
# 4  0.035667  0.000509  2.006145e-04 -4.113691e-06 -0.000012 -0.000509
#
#      ddpdw1    ddpdw2    ddpdw3    ddpdw4  ...  ddpdw3_kf  ddpdw4_kf  \
# 0  0.848444  0.000227  0.000045 -0.000094  ...   0.000000   0.000000
# 1  0.776263  0.005779  0.002238 -0.000088  ...   0.002238  -0.000088
# 2  0.708767  0.010814  0.004234 -0.000082  ...   0.004234  -0.000082
# 3  0.645672  0.015372  0.006046 -0.000077  ...   0.005447  -0.000078
# 4  0.586713  0.019491  0.007688 -0.000071  ...   0.007152  -0.000073
#
#    ddpdw5_kf  ddpdw6_kf  dddpddw1_kf  dddpddw2_kf  dddpddw3_kf   dddpddw4_kf  \
# 0   0.000000   0.000000     0.000000     0.000000     0.000000  0.000000e+00
# 1  -0.000265  -0.010826     0.007799     0.000058     0.000022 -8.810773e-07
# 2  -0.000248  -0.010149     0.006437     0.000160     0.000063 -7.664644e-07
# 3  -0.000237  -0.009716    -2.134869     0.154652     0.061480  1.843300e-04
# 4  -0.000221  -0.009086    -4.130425     0.293829     0.116966  3.615256e-04
#
#    dddpddw5_kf  dddpddw6_kf
# 0     0.000000     0.000000
# 1    -0.000003    -0.000109
# 2    -0.000002    -0.000095
# 3     0.000560     0.021883
# 4     0.001101     0.042806
#
# [5 rows x 30 columns]

# %%
column_tmp = [
	'dpw1', 'dpw2', 'dpw3', 'dpw4', 'dpw5', 'dpw6',
    'ddpdw1', 'ddpdw2', 'ddpdw3', 'ddpdw4', 'ddpdw5', 'ddpdw6',
    'dpw1_kf', 'dpw2_kf', 'dpw3_kf', 'dpw4_kf', 'dpw5_kf', 'dpw6_kf',
    'ddpdw1_kf', 'ddpdw2_kf', 'ddpdw3_kf', 'ddpdw4_kf', 'ddpdw5_kf', 'ddpdw6_kf',
    'dddpddw1_kf', 'dddpddw2_kf', 'dddpddw3_kf', 'dddpddw4_kf', 'dddpddw5_kf', 'dddpddw6_kf',
	]

# %%
col = 1
f, ax = plt.subplots(figsize = (15,6))
ax.plot(df['dpw{}'.format(col)], color = 'red')
ax.plot(df['dpw{}_kf'.format(col)], color = 'blue')

# %%
col = 4
f, ax = plt.subplots(figsize = (15,6))
ax.plot(df['ddpdw{}'.format(col)], color = 'red')
ax.plot(df['ddpdw{}_kf'.format(col)], color = 'blue')

# %%
col = 1
f, ax = plt.subplots(figsize = (15,6))
ax.plot(df['dddpddw{}_kf'.format(col)][3:] , color = 'blue')
