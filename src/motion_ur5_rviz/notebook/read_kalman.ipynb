# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
folder = '../src/'
fn = "tmp.csv"
path = os.path.join(folder, fn)

# %%
df= pd.read_csv(path)

# %%
column_tmp = [
	'dpw1', 'dpw2', 'dpw3', 'dpw4', 'dpw5', 'dpw6',
    'ddpdw1', 'ddpdw2', 'ddpdw3', 'ddpdw4', 'ddpdw5', 'ddpdw6',
    'dpw1_kf', 'dpw2_kf', 'dpw3_kf', 'dpw4_kf', 'dpw5_kf', 'dpw6_kf',
    'ddpdw1_kf', 'ddpdw2_kf', 'ddpdw3_kf', 'ddpdw4_kf', 'ddpdw5_kf', 'ddpdw6_kf',
    'dddpddw1_kf', 'dddpddw2_kf', 'dddpddw3_kf', 'dddpddw4_kf', 'dddpddw5_kf', 'dddpddw6_kf',
	]

# %%
col = 1
f, ax = plt.subplots(figsize = (15,6))
ax.plot(df['dpw{}'.format(col)], color = 'red',  linewidth = 1)
ax.plot(df['dpw{}_kf'.format(col)], color = 'blue', linestyle='--', linewidth = 3)

# %%
col = 1
f, ax = plt.subplots(figsize = (15,6))
ax.plot(df['ddpdw{}'.format(col)][1000:], color = 'red')
ax.plot(df['ddpdw{}_kf'.format(col)][1000:], color = 'blue')

# %%
col = 1
f, ax = plt.subplots(figsize = (15,6))
ax.plot(df['dddpddw{}_kf'.format(col)][1000:] , color = 'blue')
