# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
folder = '../src/'
fn = "tmp.csv"
path = os.path.join(folder, fn)

# %%
df= pd.read_csv(path)

column_tmp = [
	'dp_e_1', 'dp_e_2', 'dp_e_3', 'dp_e_4', 'dp_e_5', 'dp_e_6',
    'ddp_e_1', 'ddp_e_2', 'ddp_e_3', 'ddp_e_4', 'ddp_e_5', 'ddp_e_6',
    'dp_e_1_kf', 'dp_e_2_kf', 'dp_e_3_kf', 'dp_e_4_kf', 'dp_e_5_kf', 'dp_e_6_kf',
    'ddp_e_1_kf', 'ddp_e_2_kf', 'ddp_e_3_kf', 'ddp_e_4_kf', 'ddp_e_5_kf', 'ddp_e_6_kf',
    'dddp_e_1_kf', 'dddp_e_2_kf', 'dddp_e_3_kf', 'dddp_e_4_kf', 'dddp_e_5_kf', 'dddp_e_6_kf',
	]

col = 5
f, ax = plt.subplots(figsize = (15,6))
ax.plot(df['dpw{}'.format(col)], color = 'red',  linewidth = 1)
ax.plot(df['dpw{}_kf'.format(col)], color = 'blue', linestyle='--', linewidth = 3)

# %%
col = 1
f, ax = plt.subplots(figsize = (15,6))
ax.plot(df['ddpdw{}'.format(col)], color = 'red')
ax.plot(df['ddpdw{}_kf'.format(col)], color = 'blue')

# %%
col = 4
f, ax = plt.subplots(figsize = (15,6))
ax.plot(df['dddpddw{}_kf'.format(col)] , color = 'blue')
